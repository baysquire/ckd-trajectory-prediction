# %% [markdown]
# # Predicting CKD Trajectories - Tutorial
#
# This notebook demonstrates how to run the data generation, feature engineering, and training pipeline locally using synthetic data.

# %% [markdown]
# ## 1. Generate Synthetic Data
# Since the MIMIC-IV dataset is restricted, we provide a synthetic data generator that creates data with the same schema and approximate clinical characteristics.

# %%
# !python src/data/make_synthetic_data.py

# %% [markdown]
# ## 2. Preprocess and Build Features
# Next, we clean the data, calculate derived clinical variables (like eGFR), and split it into training, validation, and test sets.

# %%
# !python src/data/preprocess.py

# %% [markdown]
# ## 3. Train the Temporal Fusion Transformer (TFT)
# Finally, we train the TFT model on the processed dataset. The script will compare the model's predictions against a persistence baseline.

# %%
# !python src/models/train_tft.py
